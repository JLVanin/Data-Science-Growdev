# %%
file_path = '/databricks-datasets/nyctaxi/tripdata/yellow/yellow_tripdata_2019-12.csv.gz'

df = spark.read.format("csv")\
               . option("header", "true")\
               . option("inferSchema" , "true")\
               . load(file_path)

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df.count()
# Out:
# Out[3]: 6896317

# %%
import pyspark.sql.functions as F

df2 = df.groupBy('passenger_count')\
        .agg(F.count('passenger_count'))

# %%
display(df2)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>passenger_count</th><th>count(passenger_count)</th></tr></thead><tbody><tr><td>null</td><td>0</td></tr><tr><td>1</td><td>4783392</td></tr><tr><td>6</td><td>147925</td></tr><tr><td>3</td><td>303007</td></tr><tr><td>5</td><td>244887</td></tr><tr><td>9</td><td>16</td></tr><tr><td>4</td><td>164931</td></tr><tr><td>8</td><td>18</td></tr><tr><td>7</td><td>45</td></tr><tr><td>2</td><td>1075747</td></tr><tr><td>0</td><td>125331</td></tr></tbody></table></div>

# %%
dec_2019 = df.withColumn('day_of_month',\
            F.dayofmonth(df.tpep_pickup_datetime))
             
rider_day = dec_2019.groupBy('day_of_month').count()

# %%
display(rider_day)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
